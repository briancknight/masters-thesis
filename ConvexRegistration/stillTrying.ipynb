# %%
import numpy as np
import cvxpy as cvx
from scipy import sparse
from imTools import *
from Taylor08 import *
from convexHullPlot import *
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import SimpleITK as sitk
from Transforms import *
from Registration import *
import time

# %%
base = readImage('images/BrainT1Slice.png', (100,100))
target = readImage('images/BrainT1SliceR10X13Y17.png', (100,100))
(m, n, _) = base.shape

# %%
(outIm, tx) = registerImages(base, target, 'euler', 'mattes')

# %%
outIm = transformImage(base, tx, 0)

# %%
plt.imshow(outIm)

# %%
plt.imshow(target - outIm)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
