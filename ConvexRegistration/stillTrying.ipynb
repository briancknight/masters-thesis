# %%
import numpy as np
import cvxpy as cvx
from scipy import sparse
from imTools import *
from Taylor08 import *
from convexHullPlot import *
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import SimpleITK as sitk
from Transforms import *
from Registration import *
import time

# %%
base = readImage('images/BrainProtonDensitySlice.png')
target = readImage('images/BrainProtonDensitySliceShifted13x17y.png')
# base = readImage('images/konaResize.png')
# target = readImage('images/konaTransform.png')
(m, n, _) = base.copy().shape

# %%
(Ax, Ay, Iz, b, C) = getConstraintCoeffs(target, base, 5, 'firstOrder')

# %%
generateExampleFigures()
